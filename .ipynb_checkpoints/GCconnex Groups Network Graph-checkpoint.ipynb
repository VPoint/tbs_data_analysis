# %%
import pandas as pd
import pylab as pl
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
import re
import networkx as nx
import csv
import json

# %%
data_path = r"C:/Users/Owner/Documents/Work_transfer/Data/GCconnex_collab/"
group_data_path = r"C:/Users/Owner/Documents/Work_transfer/Data/GCconnex/"
gephi_path = r"C:/Users/Owner/Documents/Work_transfer/Gephi/GCconnex/"

# %%
nodes = []
edges = []
details = {}
groups = {}

# %%
# Read CSV of UID and names and create nodes for each user

with open(os.path.join(data_path+"gcc_user_info_update_2015-09-03.csv"), "r", encoding="latin1") as f:
    reader = csv.reader(f, delimiter=',')
    next(reader)

    for row in reader:
        uid, email, start_date = row
        ampersand = email.find("@")
        name = email[0:ampersand]
        department = email[ampersand + 1:]
        details[uid] = {'label':"", 'department':department, 'active': "", 'end': '01-09-2015', 'start': start_date}

# %%
# Get group names
with open(os.path.join(group_data_path, "gcconnex_group_info.csv"), "r+", encoding="latin1") as f:
    reader = csv.reader(f, delimiter=",")
    next(reader)
    
    for row in reader:
        group_id, name, created, last_active, owner = row
        groups[group_id] = name
        details[group_id] = {'label':name, 'department':'group', 'active': last_active, 'end': '01-09-2015', 'start': created}
        edges.append([group_id, owner])
        
# Get group membership and associations
with open(os.path.join(group_data_path, "gcconnex_group_members.csv"), "r+", encoding="latin1") as f:
    reader = csv.reader(f, delimiter=",")
    next(reader)
    
    for row in reader:
        uid, group_id, date = row
        edges.append([uid, group_id])

# %%
G=nx.DiGraph()

# %%
for k,v in details.items():
    G.add_node(k, label=v['label'], department=v['department'], activity=v['active'], start=v['start'], end=v['end'])
    
for link in edges:
    G.add_edge(link[0], link[1])

# %%
details
# Out:
# {'202114': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-09-2012'},
#  '3263025': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-11-2013'},
#  '8412358': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-01-2015'},
#  '9546467': {'active': '20-02-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'CMHC',
#   'start': '20-02-2015'},
#  '2687044': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-09-2013'},
#  '12811043': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-06-2015'},
#  '7130717': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-11-2014'},
#  '110856': {'active': '31-12-1969',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Interdepartmental Biotechnology Group',
#   'start': '21-01-2011'},
#  '6596016': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-10-2014'},
#  '127195': {'active': '',
#   'department': 'ainc-inac.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-05-2011'},
#  '3269317': {'active': '',
#   'department': 'pmprb-cepmb.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-11-2013'},
#  '6444307': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-10-2014'},
#  '167567': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-01-2012'},
#  '11838380': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-05-2015'},
#  '5318722': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-07-2014'},
#  '638129': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-07-2013'},
#  '252829': {'active': '',
#   'department': 'parl.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-03-2013'},
#  '7525931': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-12-2014'},
#  '12228356': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-06-2015'},
#  '9743807': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-02-2015'},
#  '4293666': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-03-2014'},
#  '151562': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-10-2011'},
#  '7397235': {'active': '',
#   'department': 'nrcan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-12-2014'},
#  '8520372': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-01-2015'},
#  '7554990': {'active': '',
#   'department': 'cisr-irb.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-12-2014'},
#  '12992644': {'active': '',
#   'department': 'ps-sp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-07-2015'},
#  '13216907': {'active': '',
#   'department': 'elections.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-07-2015'},
#  '5199528': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-06-2014'},
#  '4401522': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-03-2014'},
#  '3377828': {'active': '22-11-2013',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'CCSC Social Comittee',
#   'start': '22-11-2013'},
#  '7000399': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-11-2014'},
#  '57278': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-03-2010'},
#  '1076334': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-08-2013'},
#  '4941455': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-06-2014'},
#  '299371': {'active': '',
#   'department': 'psc-cfp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-06-2013'},
#  '4130053': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-02-2014'},
#  '14349904': {'active': '',
#   'department': 'catsa.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-08-2015'},
#  '9177462': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-02-2015'},
#  '4345654': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-03-2014'},
#  '258539': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-04-2013'},
#  '5212720': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-06-2014'},
#  '353731': {'active': '',
#   'department': 'psc-cfp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-06-2013'},
#  '169870': {'active': '02-07-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'ASFC Communications, rÃ©gion du QuÃ©bec',
#   'start': '25-01-2012'},
#  '262404': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-04-2013'},
#  '2513297': {'active': '18-12-2013',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'HR @ Justice',
#   'start': '25-09-2013'},
#  '4418600': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-04-2014'},
#  '135185': {'active': '',
#   'department': 'inac.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-07-2011'},
#  '7237110': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-11-2014'},
#  '198426': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-08-2012'},
#  '10680233': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-04-2015'},
#  '4358409': {'active': '',
#   'department': 'infc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-03-2014'},
#  '13394481': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-07-2015'},
#  '227820': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-01-2013'},
#  '4775676': {'active': '',
#   'department': 'vac-acc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-05-2014'},
#  '55923': {'active': '',
#   'department': 'lac-bac.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-02-2010'},
#  '5228642': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-06-2014'},
#  '8068614': {'active': '',
#   'department': 'priv.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-01-2015'},
#  '4520032': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-04-2014'},
#  '5181491': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-06-2014'},
#  '72066': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-05-2010'},
#  '9635127': {'active': '',
#   'department': 'csps-efpc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-02-2015'},
#  '6125302': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-09-2014'},
#  '3665487': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-12-2013'},
#  '4663390': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-05-2014'},
#  '7291687': {'active': '09-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Workplace Policies, Programs, Engagement and Ethics / Politiques, Programmes, Engagement et Ã\x89thique en milieu de travail',
#   'start': '28-11-2014'},
#  '11569781': {'active': '06-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'MD RADAR WG',
#   'start': '11-05-2015'},
#  '122467': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-04-2011'},
#  '12599502': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-06-2015'},
#  '11899710': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-05-2015'},
#  '4614': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-06-2009'},
#  '862315': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-07-2013'},
#  '1629720': {'active': '',
#   'department': 'wd-deo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-08-2013'},
#  '52901': {'active': '28-05-2013',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Canada Business Nova Scotia',
#   'start': '04-02-2010'},
#  '6390289': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-10-2014'},
#  '8455344': {'active': '',
#   'department': 'ssc-spc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-01-2015'},
#  '5317364': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-07-2014'},
#  '293864': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-06-2013'},
#  '5723777': {'active': '',
#   'department': 'cb-cda.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-08-2014'},
#  '13444840': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-07-2015'},
#  '4948324': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-06-2014'},
#  '405358': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-06-2013'},
#  '7764446': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-12-2014'},
#  '8586420': {'active': '',
#   'department': 'tribunal.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-01-2015'},
#  '3289204': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-11-2013'},
#  '2942728': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-10-2013'},
#  '1531106': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-08-2013'},
#  '4331833': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-03-2014'},
#  '10514302': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-03-2015'},
#  '4926611': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-06-2014'},
#  '216033': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-11-2012'},
#  '2250019': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-09-2013'},
#  '3714570': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-01-2014'},
#  '220297': {'active': '',
#   'department': 'ps-sp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-12-2012'},
#  '272565': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-05-2013'},
#  '4174781': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-02-2014'},
#  '11050': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-06-2009'},
#  '6441': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-06-2009'},
#  '5386714': {'active': '',
#   'department': 'pco-bcp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-07-2014'},
#  '176718': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-02-2012'},
#  '4589320': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-04-2014'},
#  '7043495': {'active': '11-03-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'ETS/ SCT',
#   'start': '18-11-2014'},
#  '6488891': {'active': '',
#   'department': 'vac-acc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-10-2014'},
#  '684849': {'active': '',
#   'department': 'dec-ced.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-07-2013'},
#  '5065959': {'active': '03-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Court cases of interest / Instances dâ\x80\x99intÃ©rÃªt devant les tribunaux',
#   'start': '16-06-2014'},
#  '4484058': {'active': '',
#   'department': 'NRCan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-04-2014'},
#  '4918626': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-06-2014'},
#  '251237': {'active': '',
#   'department': 'ps-sp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-03-2013'},
#  '401260': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-06-2013'},
#  '14098138': {'active': '',
#   'department': 'tpsgc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-08-2015'},
#  '863844': {'active': '',
#   'department': 'ps-sp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-07-2013'},
#  '158723': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-11-2011'},
#  '12508976': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-06-2015'},
#  '5370554': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-07-2014'},
#  '8531762': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-01-2015'},
#  '826868': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-07-2013'},
#  '4303249': {'active': '14-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'GCDOCS Project Managers',
#   'start': '11-03-2014'},
#  '1881510': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-09-2013'},
#  '4124476': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-02-2014'},
#  '224182': {'active': '',
#   'department': 'psc-cfp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-12-2012'},
#  '13836901': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-08-2015'},
#  '127439': {'active': '',
#   'department': 'inac-ainc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-05-2011'},
#  '153214': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-10-2011'},
#  '10648244': {'active': '',
#   'department': 'vac-acc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-04-2015'},
#  '7231753': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-11-2014'},
#  '14097387': {'active': '',
#   'department': 'tpsgc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-08-2015'},
#  '7317230': {'active': '01-12-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'CBSA - Environmental Operations Division',
#   'start': '01-12-2014'},
#  '5228545': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-06-2014'},
#  '14096313': {'active': '',
#   'department': 'tpsgc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-08-2015'},
#  '5464128': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-07-2014'},
#  '9601892': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-02-2015'},
#  '8808407': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-01-2015'},
#  '7328429': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-12-2014'},
#  '6277093': {'active': '',
#   'department': 'pco-bcp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-10-2014'},
#  '254343': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-04-2013'},
#  '719863': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-07-2013'},
#  '14104918': {'active': '',
#   'department': 'pwgsc-tpsgc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-08-2015'},
#  '7175124': {'active': '26-11-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'TCCA EEDA Collaboration / Knowledge Base',
#   'start': '25-11-2014'},
#  '3263312': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-11-2013'},
#  '2015384': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-09-2013'},
#  '5469419': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-07-2014'},
#  '5522960': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-07-2014'},
#  '13209377': {'active': '',
#   'department': 'agr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-07-2015'},
#  '6670473': {'active': '',
#   'department': 'phac-aspc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-10-2014'},
#  '11060685': {'active': '',
#   'department': 'nrcan-rncan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-04-2015'},
#  '64122': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-03-2010'},
#  '2774747': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-10-2013'},
#  '12588801': {'active': '',
#   'department': 'pwgsc-tpsgc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-06-2015'},
#  '6510279': {'active': '',
#   'department': 'phac-aspc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-10-2014'},
#  '6697084': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-10-2014'},
#  '12853924': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-06-2015'},
#  '106819': {'active': '31-12-1969',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': "Sophie's Test Group",
#   'start': '10-12-2010'},
#  '13565100': {'active': '',
#   'department': 'ssc-spc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-07-2015'},
#  '6351971': {'active': '',
#   'department': 'feddevontario.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-10-2014'},
#  '4175933': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-02-2014'},
#  '1419309': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-08-2013'},
#  '13842733': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-08-2015'},
#  '243303': {'active': '',
#   'department': 'cmhc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-03-2013'},
#  '11644689': {'active': '',
#   'department': 'sshrc-crsh.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-05-2015'},
#  '14027962': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-08-2015'},
#  '119523': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-03-2011'},
#  '3594569': {'active': '',
#   'department': 'nrcan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-12-2013'},
#  '277870': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-05-2013'},
#  '7068623': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-11-2014'},
#  '1616832': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-08-2013'},
#  '245116': {'active': '',
#   'department': 'ps.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-03-2013'},
#  '4386490': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-03-2014'},
#  '21638': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-07-2009'},
#  '4160451': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-02-2014'},
#  '7129680': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-11-2014'},
#  '212606': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-11-2012'},
#  '5076519': {'active': '',
#   'department': 'pc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-06-2014'},
#  '4918051': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-06-2014'},
#  '686128': {'active': '19-07-2013',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'AAA Learning Group',
#   'start': '19-07-2013'},
#  '10397509': {'active': '',
#   'department': 'canada.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-03-2015'},
#  '11415188': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-05-2015'},
#  '11621581': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-05-2015'},
#  '5713378': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-08-2014'},
#  '6371218': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-10-2014'},
#  '164511': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-12-2011'},
#  '4155653': {'active': '',
#   'department': 'psc-cfp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-02-2014'},
#  '4887802': {'active': '',
#   'department': 'pc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-05-2014'},
#  '3417175': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-11-2013'},
#  '7016120': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-11-2014'},
#  '2939827': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-10-2013'},
#  '8401717': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-01-2015'},
#  '4146313': {'active': '',
#   'department': 'wd.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-02-2014'},
#  '5936013': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-09-2014'},
#  '3718121': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-01-2014'},
#  '7706': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-06-2009'},
#  '27554': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-09-2009'},
#  '4770394': {'active': '25-06-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Ontario Region Sustainable Development Committee (CRA)',
#   'start': '14-05-2014'},
#  '5976844': {'active': '',
#   'department': 'ssc-spc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-09-2014'},
#  '5250509': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-07-2014'},
#  '9960275': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-03-2015'},
#  '6280988': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-10-2014'},
#  '4539823': {'active': '',
#   'department': 'cfp-psc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-04-2014'},
#  '4218574': {'active': '',
#   'department': 'rncan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-02-2014'},
#  '14150254': {'active': '',
#   'department': 'pc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-08-2015'},
#  '12472664': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-06-2015'},
#  '1809879': {'active': '',
#   'department': 'grainscanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-09-2013'},
#  '8944278': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-02-2015'},
#  '35035': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-11-2009'},
#  '3028808': {'active': '22-07-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Idea Incubator Board',
#   'start': '17-10-2013'},
#  '5422075': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-07-2014'},
#  '12487488': {'active': '',
#   'department': 'phac-aspc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-06-2015'},
#  '5902120': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-09-2014'},
#  '473625': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-07-2013'},
#  '6387275': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-10-2014'},
#  '8437024': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-01-2015'},
#  '9474533': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-02-2015'},
#  '5882061': {'active': '',
#   'department': 'ssc-spc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-08-2014'},
#  '2008183': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-09-2013'},
#  '5092941': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-06-2014'},
#  '8570474': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-01-2015'},
#  '8731660': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-01-2015'},
#  '363038': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-06-2013'},
#  '2102936': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-09-2013'},
#  '245078': {'active': '',
#   'department': 'ps-sp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-03-2013'},
#  '38728': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-11-2009'},
#  '11473176': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-05-2015'},
#  '4777613': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-05-2014'},
#  '7175394': {'active': '01-12-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'CSC Intranet Revamp Team',
#   'start': '25-11-2014'},
#  '9936596': {'active': '05-03-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Test',
#   'start': '05-03-2015'},
#  '4889602': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-05-2014'},
#  '4699632': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-05-2014'},
#  '13080308': {'active': '',
#   'department': 'bac-lac.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-07-2015'},
#  '8493041': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-01-2015'},
#  '6145861': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-09-2014'},
#  '942287': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-08-2013'},
#  '2839064': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-10-2013'},
#  '1383943': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-08-2013'},
#  '116385': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-02-2011'},
#  '7990796': {'active': '',
#   'department': 'ncc-ccn.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-12-2014'},
#  '130078': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-06-2011'},
#  '10050969': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-03-2015'},
#  '3866483': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-01-2014'},
#  '6498463': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-10-2014'},
#  '80066': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-06-2010'},
#  '4234726': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-03-2014'},
#  '939555': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-08-2013'},
#  '127483': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-05-2011'},
#  '45328': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-12-2009'},
#  '207245': {'active': '',
#   'department': 'rcmp-grc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-09-2012'},
#  '13764637': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-07-2015'},
#  '10658044': {'active': '13-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Pacific (BC/Yukon) Interdepartmental Staffing Council',
#   'start': '08-04-2015'},
#  '212273': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-10-2012'},
#  '193843': {'active': '',
#   'department': 'agr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-06-2012'},
#  '11186580': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-04-2015'},
#  '12554430': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-06-2015'},
#  '3376259': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-11-2013'},
#  '10634369': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-04-2015'},
#  '210294': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-10-2012'},
#  '4447063': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-04-2014'},
#  '14141176': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-08-2015'},
#  '3644313': {'active': '',
#   'department': 'rcmp-grc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-12-2013'},
#  '11465304': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-05-2015'},
#  '12642828': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-06-2015'},
#  '4471582': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-04-2014'},
#  '3767794': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-01-2014'},
#  '696346': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-07-2013'},
#  '11387202': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-05-2015'},
#  '13432195': {'active': '',
#   'department': 'elections.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-07-2015'},
#  '58187': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-03-2010'},
#  '6184213': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-09-2014'},
#  '10519528': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-03-2015'},
#  '12488318': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-06-2015'},
#  '4553160': {'active': '',
#   'department': 'spc-ssc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-04-2014'},
#  '1828404': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-09-2013'},
#  '2861697': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-10-2013'},
#  '132383': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-06-2011'},
#  '13535545': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-07-2015'},
#  '5072942': {'active': '30-12-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'NRCan&#039;s Administrative Professionals Network (APN)',
#   'start': '16-06-2014'},
#  '2820534': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-10-2013'},
#  '209994': {'active': '',
#   'department': 'vac-acc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-10-2012'},
#  '7160606': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-11-2014'},
#  '4101675': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-02-2014'},
#  '5949312': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-09-2014'},
#  '4756412': {'active': '',
#   'department': 'pco-bcp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-05-2014'},
#  '4566537': {'active': '',
#   'department': 'pc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-04-2014'},
#  '176307': {'active': '',
#   'department': 'grainscanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-02-2012'},
#  '12265173': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-06-2015'},
#  '3313021': {'active': '',
#   'department': 'irb-cisr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-11-2013'},
#  '14104208': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-08-2015'},
#  '13692134': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-07-2015'},
#  '3854818': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-01-2014'},
#  '126136': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-04-2011'},
#  '5811210': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-08-2014'},
#  '3242201': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-11-2013'},
#  '5273804': {'active': '',
#   'department': 'rcmp-grc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-07-2014'},
#  '191326': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-06-2012'},
#  '17923': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-07-2009'},
#  '3727149': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-01-2014'},
#  '6365978': {'active': '',
#   'department': 'cmhc-schl.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-10-2014'},
#  '4308188': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-03-2014'},
#  '7038533': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-11-2014'},
#  '9616197': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-02-2015'},
#  '11926907': {'active': '',
#   'department': 'psc-cfp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-05-2015'},
#  '9482158': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-02-2015'},
#  '4795686': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-05-2014'},
#  '4646062': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-05-2014'},
#  '12413330': {'active': '',
#   'department': 'canada.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-06-2015'},
#  '9919152': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-03-2015'},
#  '1327585': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-08-2013'},
#  '4467963': {'active': '',
#   'department': 'INSPECTION.GC.CA',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-04-2014'},
#  '6222223': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-10-2014'},
#  '6278823': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-10-2014'},
#  '5457926': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-07-2014'},
#  '9456842': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-02-2015'},
#  '12474678': {'active': '',
#   'department': 'pmprb-cepmb.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-06-2015'},
#  '2007930': {'active': '',
#   'department': 'infc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-09-2013'},
#  '11786590': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-05-2015'},
#  '1510007': {'active': '',
#   'department': 'acoa-apeca.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-08-2013'},
#  '3636586': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-12-2013'},
#  '3258973': {'active': '24-06-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'CPP/EI Appeals - Nine Priorities',
#   'start': '06-11-2013'},
#  '6019424': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-09-2014'},
#  '5077968': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-06-2014'},
#  '4402996': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-03-2014'},
#  '6387785': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-10-2014'},
#  '2382748': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-09-2013'},
#  '4806983': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-05-2014'},
#  '10381305': {'active': '',
#   'department': 'nrc-cnrc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-03-2015'},
#  '5112879': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-06-2014'},
#  '6558723': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-10-2014'},
#  '325489': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-06-2013'},
#  '11594125': {'active': '',
#   'department': 'nrc-cnrc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-05-2015'},
#  '4141690': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-02-2014'},
#  '23832': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-08-2009'},
#  '7973125': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-12-2014'},
#  '5893683': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-09-2014'},
#  '6275311': {'active': '',
#   'department': 'cbsa.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-10-2014'},
#  '8275924': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-01-2015'},
#  '4972409': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-06-2014'},
#  '4880283': {'active': '',
#   'department': 'pbc-clcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-05-2014'},
#  '7764391': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-12-2014'},
#  '6976953': {'active': '',
#   'department': 'tpsgc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-11-2014'},
#  '14158865': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-08-2015'},
#  '12754735': {'active': '',
#   'department': 'phac-aspc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-06-2015'},
#  '3697587': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-01-2014'},
#  '310521': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-06-2013'},
#  '3738960': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-01-2014'},
#  '3280579': {'active': '',
#   'department': 'asc-csa.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-11-2013'},
#  '7552759': {'active': '',
#   'department': 'agr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-12-2014'},
#  '12118884': {'active': '28-05-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'LIF Quarterly Newsletter',
#   'start': '28-05-2015'},
#  '7748775': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-12-2014'},
#  '97835': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-10-2010'},
#  '3139344': {'active': '',
#   'department': 'chrc-ccdp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-10-2013'},
#  '4927747': {'active': '04-06-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'PM issues',
#   'start': '04-06-2014'},
#  '13407184': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-07-2015'},
#  '294786': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-06-2013'},
#  '7243914': {'active': '',
#   'department': 'ssc-spc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-11-2014'},
#  '5815637': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-08-2014'},
#  '13914363': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-08-2015'},
#  '5587581': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-08-2014'},
#  '4363631': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-03-2014'},
#  '6195950': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-09-2014'},
#  '240988': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-02-2013'},
#  '9443363': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-02-2015'},
#  '743614': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-07-2013'},
#  '2278849': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '19-09-2013'},
#  '75539': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-05-2010'},
#  '1172505': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-08-2013'},
#  '322190': {'active': '',
#   'department': 'cnsc-ccsn.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-06-2013'},
#  '2785549': {'active': '14-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'GC Enterprise Security Architecture (GC ESA)',
#   'start': '03-10-2013'},
#  '10545320': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-03-2015'},
#  '13327475': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-07-2015'},
#  '12676206': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-06-2015'},
#  '12527028': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-06-2015'},
#  '258488': {'active': '',
#   'department': 'csps-efpc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-04-2013'},
#  '203152': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-09-2012'},
#  '3305706': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-11-2013'},
#  '4648946': {'active': '14-01-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Committee for the Advancement of Native Employment (CANE) - BC Region',
#   'start': '07-05-2014'},
#  '190535': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-06-2012'},
#  '10613823': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-04-2015'},
#  '10094478': {'active': '',
#   'department': 'canada.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-03-2015'},
#  '237934': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-02-2013'},
#  '1375089': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-08-2013'},
#  '8731475': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-01-2015'},
#  '13416506': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-07-2015'},
#  '9349216': {'active': '',
#   'department': 'feddevontario.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-02-2015'},
#  '3728091': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-01-2014'},
# ...
#   'department': 'CRA-ARC.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-10-2014'},
#  '11639961': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-05-2015'},
#  '4589360': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-04-2014'},
#  '3011075': {'active': '16-10-2013',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'willows',
#   'start': '16-10-2013'},
#  '2326095': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-09-2013'},
#  '3540721': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '10-12-2013'},
#  '5936389': {'active': '',
#   'department': 'aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-09-2014'},
#  '5906379': {'active': '',
#   'department': 'aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-09-2014'},
#  '3261724': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-11-2013'},
#  '135111': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-07-2011'},
#  '4749131': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-05-2014'},
#  '123215': {'active': '',
#   'department': 'ps-sp.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-04-2011'},
#  '3376242': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-11-2013'},
#  '1356967': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-08-2013'},
#  '1542756': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-08-2013'},
#  '105737': {'active': '',
#   'department': 'aadnc-aandc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-12-2010'},
#  '7705': {'active': '13-07-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Alberta Federal Council Youth Network - oXYgen',
#   'start': '12-06-2009'},
#  '4171693': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-02-2014'},
#  '1657728': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-09-2013'},
#  '8331642': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-01-2015'},
#  '12772090': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-06-2015'},
#  '7617829': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-12-2014'},
#  '4375251': {'active': '',
#   'department': 'agr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-03-2014'},
#  '399925': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-06-2013'},
#  '42173': {'active': '',
#   'department': 'tc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-12-2009'},
#  '197242': {'active': '',
#   'department': 'nrcan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-07-2012'},
#  '7301381': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-12-2014'},
#  '4169494': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-02-2014'},
#  '4462013': {'active': '',
#   'department': 'vac-acc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-04-2014'},
#  '453799': {'active': '',
#   'department': 'rcmp-grc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-07-2013'},
#  '9442714': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-02-2015'},
#  '12356037': {'active': '',
#   'department': 'cfp-psc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-06-2015'},
#  '141563': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '25-08-2011'},
#  '553570': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-07-2013'},
#  '9153012': {'active': '11-02-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Product Installation Guidelines (for IMSD staff)',
#   'start': '11-02-2015'},
#  '137894': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-07-2011'},
#  '12242530': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-06-2015'},
#  '1805428': {'active': '',
#   'department': 'fin.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-09-2013'},
#  '5210714': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-06-2014'},
#  '4308637': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-03-2014'},
#  '14298535': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-08-2015'},
#  '4393191': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-03-2014'},
#  '1067648': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-08-2013'},
#  '12686692': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-06-2015'},
#  '282237': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-05-2013'},
#  '122975': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-04-2011'},
#  '215868': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-11-2012'},
#  '12066434': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-05-2015'},
#  '1953735': {'active': '',
#   'department': 'asc-csa.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-09-2013'},
#  '8292238': {'active': '',
#   'department': 'irsad-sapi.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-01-2015'},
#  '1311943': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-08-2013'},
#  '11182006': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-04-2015'},
#  '4608320': {'active': '11-07-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'NS RMT',
#   'start': '02-05-2014'},
#  '5879444': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-08-2014'},
#  '261069': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-04-2013'},
#  '200579': {'active': '',
#   'department': 'vac-acc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-08-2012'},
#  '6036489': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-09-2014'},
#  '8927807': {'active': '',
#   'department': 'agr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '03-02-2015'},
#  '4726716': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-05-2014'},
#  '13814564': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-07-2015'},
#  '120972': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-03-2011'},
#  '802311': {'active': '',
#   'department': 'justice.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-07-2013'},
#  '1983670': {'active': '',
#   'department': 'cra.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-09-2013'},
#  '2043971': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '13-09-2013'},
#  '98309': {'active': '',
#   'department': 'NRCan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-10-2010'},
#  '130698': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-06-2011'},
#  '10530424': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-03-2015'},
#  '10623678': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-04-2015'},
#  '3107767': {'active': '11-03-2014',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Client Computing Services Directorate (CCSD) Community -  Working Group',
#   'start': '22-10-2013'},
#  '1192327': {'active': '',
#   'department': 'cra.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-08-2013'},
#  '5897141': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '02-09-2014'},
#  '6725186': {'active': '',
#   'department': 'statcan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-10-2014'},
#  '9617407': {'active': '',
#   'department': 'tbs-sct.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-02-2015'},
#  '12341144': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-06-2015'},
#  '8520624': {'active': '',
#   'department': 'cbsa-asfc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-01-2015'},
#  '230589': {'active': '',
#   'department': 'pch.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-01-2013'},
#  '13650495': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-07-2015'},
#  '5937094': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-09-2014'},
#  '3869419': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-01-2014'},
#  '5386463': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-07-2014'},
#  '10641964': {'active': '',
#   'department': 'dfo-mpo.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '07-04-2015'},
#  '116208': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-02-2011'},
#  '5037562': {'active': '06-02-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'DG IT Security Tripartite (DG ITST)',
#   'start': '13-06-2014'},
#  '6135104': {'active': '',
#   'department': 'inspection.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-09-2014'},
#  '4814651': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-05-2014'},
#  '4145772': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '18-02-2014'},
#  '3450223': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-12-2013'},
#  '12689416': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-06-2015'},
#  '1542038': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-08-2013'},
#  '6010782': {'active': '',
#   'department': 'csc-scc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '11-09-2014'},
#  '9958835': {'active': '',
#   'department': 'ic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-03-2015'},
#  '148562': {'active': '',
#   'department': 'Ceaa-acee.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '05-10-2011'},
#  '26350': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-09-2009'},
#  '509046': {'active': '',
#   'department': 'rcmp-grc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-07-2013'},
#  '12544828': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-06-2015'},
#  '12310784': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '04-06-2015'},
#  '12016769': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '26-05-2015'},
#  '1824265': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-09-2013'},
#  '903488': {'active': '',
#   'department': 'tpsgc-pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '01-08-2013'},
#  '211836': {'active': '',
#   'department': 'international.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '24-10-2012'},
#  '1539225': {'active': '',
#   'department': 'cra.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-08-2013'},
#  '8582681': {'active': '26-01-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'XXXX Bilateral meeting February 2015',
#   'start': '26-01-2015'},
#  '200114': {'active': '',
#   'department': 'agr.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '27-08-2012'},
#  '8394641': {'active': '',
#   'department': 'cfp-psc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-01-2015'},
#  '10533349': {'active': '',
#   'department': 'statcan.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '30-03-2015'},
#  '12575737': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-06-2015'},
#  '7110514': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '20-11-2014'},
#  '1438627': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '22-08-2013'},
#  '13307721': {'active': '',
#   'department': 'cra-arc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-07-2015'},
#  '3260155': {'active': '',
#   'department': 'asc-csa.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '06-11-2013'},
#  '1356882': {'active': '',
#   'department': 'cra.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-08-2013'},
#  '7950360': {'active': '',
#   'department': 'grainscanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-12-2014'},
#  '4893351': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '29-05-2014'},
#  '268714': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-05-2013'},
#  '8377135': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '15-01-2015'},
#  '12418270': {'active': '09-06-2015',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Ontario Region Programs Team',
#   'start': '09-06-2015'},
#  '12085914': {'active': '',
#   'department': 'ec.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '28-05-2015'},
#  '10561273': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '31-03-2015'},
#  '10658218': {'active': '',
#   'department': 'forces.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '08-04-2015'},
#  '9098083': {'active': '',
#   'department': 'hrsdc-rhdcc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '09-02-2015'},
#  '4798272': {'active': '',
#   'department': 'aandc-aadnc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '16-05-2014'},
#  '5325107': {'active': '',
#   'department': 'hc-sc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '14-07-2014'},
#  '1374824': {'active': '',
#   'department': 'pwgsc.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '21-08-2013'},
#  '6013959': {'active': '',
#   'department': 'cic.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '12-09-2014'},
#  '132587': {'active': '',
#   'department': 'bankofcanada.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '17-06-2011'},
#  '12152': {'active': '',
#   'department': 'servicecanada.gc.ca',
#   'end': '01-09-2015',
#   'label': '',
#   'start': '23-06-2009'},
#  '530395': {'active': '17-07-2013',
#   'department': 'group',
#   'end': '01-09-2015',
#   'label': 'Prairie Region - Reverse Mentoring Online',
#   'start': '10-07-2013'},
#  ...}

# %%
# Write to Graphml format
nx.write_graphml(G,os.path.join(gephi_path,"GCconnex_groups_2015_09_17.graphml"))

# %% [markdown]
# ### Now open up Gephi and play with your data!
